# %%
import pandas as pd
import numpy as np

# %%
airports = pd.read_csv('data/airports.csv')
airport_freq = pd.read_csv('data/airport-frequencies.csv')
runways = pd.read_csv('data/runways.csv')

# %%
airports.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
airport_freq.head()
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
runways.head(-3)
# Out:
#            id  airport_ref airport_ident  length_ft  width_ft surface  \
# 0      269408         6523           00A       80.0      80.0  ASPH-G
# 1      255155         6524          00AK     2500.0      70.0    GRVL
# 2      254165         6525          00AL     2300.0     200.0    TURF
# 3      270932         6526          00AR       40.0      40.0   GRASS
# 4      322128       322127          00AS     1450.0      60.0    Turf
# ...       ...          ...           ...        ...       ...     ...
# 44162  327703       327451          ZYSQ     8202.0     148.0     NaN
# 44163  235188        27242          ZYTL    10827.0     148.0     CON
# 44164  354938       307013          ZYTN     7546.0       NaN     NaN
# 44165  235186        27243          ZYTX    10499.0     148.0     CON
# 44166  235169        27244          ZYYJ     8530.0     148.0     CON
#
#        lighted  closed le_ident  le_latitude_deg  le_longitude_deg  \
# ...

# %%
"""
SELECT ... FROM ...WHERE
GROUPBY...HAVING
ORDERBY ASC/DESC
LIMIT HAVING
"""

#Select * from airports limit 3
airports.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %%
#select * from airports where ident = 'KLAX'
airports[airports['ident']=='KLAX']
# Out:
#          id ident           type                               name  \
# 36253  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 36253     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 36253      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                      home_link  \
# 36253  https://www.flylax.com/
#
#                                           wikipedia_link keywords
# 36253  https://en.wikipedia.org/wiki/Los_Angeles_Inte...      NaN

# %%
#select id from airports where ident = 'KLAX'
airports[airports['ident']=='KLAX'].id
# Out:
# 36253    3632
# Name: id, dtype: int64

# %%
#select id,type from airports where ident = 'KLAX'
airports[airports['ident']=='KLAX'][['id','type']]
# Out:
#          id           type
# 36253  3632  large_airport

# %%
#select distinct type from airport
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
#select * from airports where iso_region='US-CA' and type='seaplane-base'
airports[(airports['iso_region']=='US-CA') & (airports['type']=='large_airport')].head(2)
# Out:
#           id ident           type                               name  \
# 34858  19517  KCMA  large_airport    Camarillo International Airport
# 36253   3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 34858     34.213699    -119.094002          77.0       NaN          US
# 36253     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 34858      US-CA    Camarillo                no     KCMA       NaN        CMA
# 36253      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                      home_link  \
# 34858                      NaN
# 36253  https://www.flylax.com/
#
#                                           wikipedia_link keywords
# 34858    https://en.wikipedia.org/wiki/Camarillo_Airport      NaN
# 36253  https://en.wikipedia.org/wiki/Los_Angeles_Inte...      NaN

# %%
#select ident,na,e,municipality from airports where iso_region='US-CA' and type='seaplane-base'
airports[(airports['iso_region']=='US-CA') & (airports['type']=='large_airport')][['ident','name','municipality']].head(2)
# Out:
#       ident                               name municipality
# 34858  KCMA    Camarillo International Airport    Camarillo
# 36253  KLAX  Los Angeles International Airport  Los Angeles

# %%
#Order By : default is ASC in pandas
#select * from airport_frequency where airport_ident='KLAX' order by type
airport_freq[airport_freq['airport_ident']=='KLAX'].sort_values('type')

#select * from airport_frequency where airport_ident='KLAX' order by type DESC
airport_freq[airport_freq['airport_ident']=='KLAX'].sort_values('type',ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 12100  60776         3632          KLAX  UNIC      UNICOM         122.95
# 12099  60775         3632          KLAX   TWR         TWR         119.80
# 12098  60774         3632          KLAX   OPS          AF          37.22
# 12096  60772         3632          KLAX  MISC          CG          34.50
# 12097  60773         3632          KLAX  MISC          CG         898.40
# 12095  60771         3632          KLAX   GND         GND         121.65
# 12094  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 12093  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 12092  60768         3632          KLAX  ATIS        ATIS         133.80
# 12090  60767         3632          KLAX   APP   SOCAL APP          36.07
# 12091  60766         3632          KLAX   APP   SOCAL APP         124.30

# %%
#Filter on a list of values...
#Select * from airports where type in ('balloonport','heliport')
airports[airports['type'].isin(['balloonport','heliport'])].head(3)
# Out:
#         id ident      type                             name  latitude_deg  \
# 0     6523   00A  heliport                Total Rf Heliport     40.070801
# 9   322658  00CN  heliport  Kitchen Creek Helibase Heliport     32.727374
# 15    6535  00GE  heliport                 Caffrey Heliport     33.887982
#
#     longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 0      -74.933601          11.0       NaN          US      US-PA     Bensalem
# 9     -116.459742        3350.0       NaN          US      US-CA  Pine Valley
# 15     -84.736983         957.0       NaN          US      US-GA        Hiram
#
#    scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                 no      00A       NaN        00A       NaN            NaN
# 9                 no     00CN       NaN       00CN       NaN            NaN
# 15                no     00GE       NaN       00GE       NaN            NaN
#
#    keywords
# 0       NaN
# 9       NaN
# ...

# %%
#Select * from airports where type not in ('balloonport','heliport')
airports[~airports['type'].isin(['balloonport','heliport'])].head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
# 3                no     00AL       NaN       00AL       NaN            NaN
#
#   keywords
# 1      NaN
# 2      NaN
# 3      NaN

# %%
#Groupby, COUNT, OrderBY
"""
Select iso_country,type,count(*)
from airports 
groupby iso_country,type
order by iso_country, type

"""

airports.groupby(['iso_country','type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              3
#              heliport          200
#              large_airport       4
#                               ...
# ZW           closed              6
#              heliport            5
#              large_airport       1
#              medium_airport      8
#              small_airport     135
# Length: 973, dtype: int64

# %%
"""
Select iso_country,type,count(*)
from airports 
groupby iso_country,type
order by iso_country, count(*) DESC

"""

airports.groupby(['iso_country','type']).size().to_frame('size').reset_index().sort_values(['iso_country','size'],ascending=[True, False])
# Out:
#     iso_country            type  size
# 1            AD        heliport     2
# 0            AD          closed     1
# 3            AE        heliport   200
# 7            AE   small_airport    30
# 5            AE  medium_airport     7
# ..          ...             ...   ...
# 972          ZW   small_airport   135
# 971          ZW  medium_airport     8
# 968          ZW          closed     6
# 969          ZW        heliport     5
# 970          ZW   large_airport     1
#
# [973 rows x 3 columns]

# %%
#Group by : Having
"""
select type, count(*) 
from airports 
where iso_country = 'US' 
group by type 
having count(*) > 1000 
order by count(*) desc
"""

airports[airports.iso_country == 'US'].groupby(['type']).filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    14844
# heliport          7770
# closed            5716
# dtype: int64

# %%
#aggreegate min, max, avg
"""
select max(length_ft), min(length_ft), avg(length_ft), median(length_ft) 
from runways
"""

runways.agg({'length_ft': ['min', 'max', 'mean', 'median']}).T
# Out:
#            min      max         mean  median
# length_ft  0.0  30000.0  3243.115789  2700.0

# %%
#JOIN
"""
select airport_ident, type, description, frequency_mhz 
from airport_freq 
join airports 
on airport_freq.airport_ref = airports.id 
where airports.ident = 'KLAX'
"""

airport_freq.merge(airports[airports['ident']=='KLAX'][['id']],left_on='airport_ref', right_on='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %%
#UNION ALL and UNION
"""
select name, municipality 
from airports 
where ident = 'KLAX' 
union all 
select name, municipality 
from airports 
where ident = 'KLGB'
"""

pd.concat([airports[airports.ident == 'KLAX'][['name','municipality']],airports[airports.ident == 'KLGB'][['name','municipality']]])
# Out:
#                                        name municipality
# 36253     Los Angeles International Airport  Los Angeles
# 36279  Long Beach Airport (Daugherty Field)   Long Beach

# %%
#Insert: Create new dataframe in pandas and concat the two
#create table heroes (id integer, name text);"
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})
print(df1)

#insert into heroes values (1, 'Harry Potter');
pd.concat([df1,pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})]).reset_index(drop=True)
# Out:
#    id          name
# 0   1  Harry Potter
# 1   2   Ron Weasley
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %%
#UPDATE
"""
update airports 
set home_link = 'http://www.lawa.org/welcomelax.aspx' 
where ident == 'KLAX'
"""
airports.loc[airports.ident == 'KLAX','home_link']="http://www.lawa1.org/welcomelax.aspx"
airports[airports.ident == 'KLAX']
# Out:
#          id ident           type                               name  \
# 36253  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 36253     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 36253      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                                   home_link  \
# 36253  http://www.lawa1.org/welcomelax.aspx
#
#                                           wikipedia_link keywords
# 36253  https://en.wikipedia.org/wiki/Los_Angeles_Inte...      NaN

# %%
#Delete
"""
 delete from runways where airport_ident = 'ZYYJ'
"""
print(runways[runways.airport_ident=='ZYYJ'].index)

runways.drop(index=runways[runways.airport_ident=='ZYYJ'])

runways.tail()
# Out:
#   File "/var/folders/k8/gg_m5nbs2056hm824n8k0d3m0000gq/T/ipykernel_45857/2325029431.py", line 9
#     runways.tail()
#     ^
# SyntaxError: invalid syntax
